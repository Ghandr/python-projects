# %%
tuple = (1,2,83)
tuple
# Out:
# (1, 2, 83)

# %%
tuple[2]
# Out:
# 83

# %%
tuple[:2]
# Out:
# (1, 2)

# %%
list(tuple)
# Out:
# [1, 2, 83]

# %%
tuple
# Out:
# (3, 1, 4, 1, 5, 9)

# %%
tuple[0] = 44
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-627b260acdb3> in <module>
# ----> 1 tuple[0] = 44
#
# TypeError: 'tuple' object does not support item assignment

# %%
list = list(tuple)

# %%
list
# Out:
# [3, 1, 4, 1, 5, 9]

# %%
list[0] = 44

# %%
list
# Out:
# [44, 1, 4, 1, 5, 9]
